# %%
import MySQLdb


db = MySQLdb.connect(
    "db.fastcamp.us",
    "root",
    "dkstncks",
    "world",
    charset='utf8',
)

cursor = db.cursor()

# %%
import pandas as pd


# Text Mining
# WHERE ____________ LIKE "%_________%"

SQL_QUERY = """
    SELECT *
    FROM Country
    WHERE
        GovernmentForm LIKE "%Republic%"
    ;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#     Code                                   Name      Continent  \
# 0    AGO                                 Angola         Africa
# 1    ALB                                Albania         Europe
# 2    ARG                              Argentina  South America
# 3    ARM                                Armenia           Asia
# 4    AUT                                Austria         Europe
# 5    AZE                             Azerbaijan           Asia
# 6    BDI                                Burundi         Africa
# 7    BEN                                  Benin         Africa
# 8    BFA                           Burkina Faso         Africa
# 9    BGD                             Bangladesh           Asia
# 10   BGR                               Bulgaria         Europe
# 11   BIH                 Bosnia and Herzegovina         Europe
# 12   BLR                                Belarus         Europe
# 13   BOL                                Bolivia  South America
# ...

# %%
SQL_QUERY = """
    SELECT *
    FROM Country;
"""

df = pd.read_sql(SQL_QUERY, db)

# %%
df
# Out:
#     Code                                  Name      Continent  \
# 0    ABW                                 Aruba  North America
# 1    AFG                           Afghanistan           Asia
# 2    AGO                                Angola         Africa
# 3    AIA                              Anguilla  North America
# 4    ALB                               Albania         Europe
# 5    AND                               Andorra         Europe
# 6    ANT                  Netherlands Antilles  North America
# 7    ARE                  United Arab Emirates           Asia
# 8    ARG                             Argentina  South America
# 9    ARM                               Armenia           Asia
# 10   ASM                        American Samoa        Oceania
# 11   ATA                            Antarctica     Antarctica
# 12   ATF           French Southern territories     Antarctica
# 13   ATG                   Antigua and Barbuda  North America
# ...

# %%
df["GovernmentForm"].str.contains("Republic")
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8       True
# 9       True
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16      True
# 17      True
# 18     False
# 19      True
# 20      True
# 21      True
# 22      True
# 23     False
# 24     False
# 25      True
# 26      True
# 27     False
# 28     False
# 29      True
#        ...
# 209    False
# 210     True
# 211    False
# 212    False
# 213     True
# 214     True
# 215     True
# 216    False
# 217     True
# 218     True
# 219     True
# 220     True
# 221    False
# 222     True
# 223     True
# 224     True
# 225    False
# 226    False
# 227     True
# 228    False
# 229    False
# 230     True
# 231     True
# 232    False
# 233    False
# 234     True
# 235     True
# 236     True
# 237     True
# 238     True
# Name: GovernmentForm, dtype: bool

# %%
df[df["GovernmentForm"].str.contains("Republic")]
# Out:
#     Code                                   Name      Continent  \
# 2    AGO                                 Angola         Africa
# 4    ALB                                Albania         Europe
# 8    ARG                              Argentina  South America
# 9    ARM                                Armenia           Asia
# 15   AUT                                Austria         Europe
# 16   AZE                             Azerbaijan           Asia
# 17   BDI                                Burundi         Africa
# 19   BEN                                  Benin         Africa
# 20   BFA                           Burkina Faso         Africa
# 21   BGD                             Bangladesh           Asia
# 22   BGR                               Bulgaria         Europe
# 25   BIH                 Bosnia and Herzegovina         Europe
# 26   BLR                                Belarus         Europe
# 29   BOL                                Bolivia  South America
# ...
