# %%
import MySQLdb


db = MySQLdb.connect(
    "db.fastcamp.us",
    "root",
    "dkstncks",
    "world",
    charset='utf8',
)

cursor = db.cursor()

# %%
import pandas as pd


# SQL Perspective - ORDER BY

SQL_QUERY = """
    SELECT *
    FROM Country
    ORDER BY Population DESC
    ;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#     Code                                          Name      Continent  \
# 0    CHN                                         China           Asia
# 1    IND                                         India           Asia
# 2    USA                                 United States  North America
# 3    IDN                                     Indonesia           Asia
# 4    BRA                                        Brazil  South America
# 5    PAK                                      Pakistan           Asia
# 6    RUS                            Russian Federation         Europe
# 7    BGD                                    Bangladesh           Asia
# 8    JPN                                         Japan           Asia
# 9    NGA                                       Nigeria         Africa
# 10   MEX                                        Mexico  North America
# 11   DEU                                       Germany         Europe
# ...

# %%
# Pandas Perspective - sort()

SQL_QUERY = """
    SELECT *
    FROM Country
    ;
"""

df = pd.read_sql(SQL_QUERY, db)

# %%
df.sort_values(by="Population", ascending=False)
# Out:
#     Code                                          Name      Continent  \
# 41   CHN                                         China           Asia
# 99   IND                                         India           Asia
# 223  USA                                 United States  North America
# 98   IDN                                     Indonesia           Asia
# 30   BRA                                        Brazil  South America
# 164  PAK                                      Pakistan           Asia
# 181  RUS                            Russian Federation         Europe
# 21   BGD                                    Bangladesh           Asia
# 109  JPN                                         Japan           Asia
# 155  NGA                                       Nigeria         Africa
# 135  MEX                                        Mexico  North America
# 56   DEU                                       Germany         Europe
# ...
