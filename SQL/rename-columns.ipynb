# %%
import MySQLdb


db = MySQLdb.connect(
    "db.fastcamp.us",
    "root",
    "dkstncks",
    "world",
    charset='utf8',
)

cursor = db.cursor()

# %%
import pandas as pd

# %%
# SQL Perspective - ALIAS
SQL_QUERY = """
    SELECT 
        Name 국가명,
        Continent 대륙명,
        Region 지역명
    FROM
        Country
    ;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#                                       국가명            대륙명  \
# 0                                   Aruba  North America
# 1                             Afghanistan           Asia
# 2                                  Angola         Africa
# 3                                Anguilla  North America
# 4                                 Albania         Europe
# 5                                 Andorra         Europe
# 6                    Netherlands Antilles  North America
# 7                    United Arab Emirates           Asia
# 8                               Argentina  South America
# 9                                 Armenia           Asia
# 10                         American Samoa        Oceania
# 11                             Antarctica     Antarctica
# 12            French Southern territories     Antarctica
# 13                    Antigua and Barbuda  North America
# 14                              Australia        Oceania
# ...

# %%
# Pandas Perspective - rename columns
SQL_QUERY = "SELECT * FROM Country;"
df = pd.read_sql(SQL_QUERY, db)
df
# Out:
#     Code                                  Name      Continent  \
# 0    ABW                                 Aruba  North America
# 1    AFG                           Afghanistan           Asia
# 2    AGO                                Angola         Africa
# 3    AIA                              Anguilla  North America
# 4    ALB                               Albania         Europe
# 5    AND                               Andorra         Europe
# 6    ANT                  Netherlands Antilles  North America
# 7    ARE                  United Arab Emirates           Asia
# 8    ARG                             Argentina  South America
# 9    ARM                               Armenia           Asia
# 10   ASM                        American Samoa        Oceania
# 11   ATA                            Antarctica     Antarctica
# 12   ATF           French Southern territories     Antarctica
# 13   ATG                   Antigua and Barbuda  North America
# ...

# %%
# 특정 Column 만 SELECT 하기
new_df = df[["Name", "Continent", "Region"]]

# %%
new_df
# Out:
#                                      Name      Continent  \
# 0                                   Aruba  North America
# 1                             Afghanistan           Asia
# 2                                  Angola         Africa
# 3                                Anguilla  North America
# 4                                 Albania         Europe
# 5                                 Andorra         Europe
# 6                    Netherlands Antilles  North America
# 7                    United Arab Emirates           Asia
# 8                               Argentina  South America
# 9                                 Armenia           Asia
# 10                         American Samoa        Oceania
# 11                             Antarctica     Antarctica
# 12            French Southern territories     Antarctica
# 13                    Antigua and Barbuda  North America
# 14                              Australia        Oceania
# ...

# %%
# 컬럼명 변경하기
new_df.rename(columns={
    "Name": "국가명",
    "Continent": "대륙명",
    "Region": "지역명",
})
# Out:
#                                       국가명            대륙명  \
# 0                                   Aruba  North America
# 1                             Afghanistan           Asia
# 2                                  Angola         Africa
# 3                                Anguilla  North America
# 4                                 Albania         Europe
# 5                                 Andorra         Europe
# 6                    Netherlands Antilles  North America
# 7                    United Arab Emirates           Asia
# 8                               Argentina  South America
# 9                                 Armenia           Asia
# 10                         American Samoa        Oceania
# 11                             Antarctica     Antarctica
# 12            French Southern territories     Antarctica
# 13                    Antigua and Barbuda  North America
# 14                              Australia        Oceania
# ...
