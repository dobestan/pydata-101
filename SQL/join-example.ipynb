# %%
# 유저 정보와 주소 정보를 한꺼번에 가져오기
# ( 단, 현재 유저 정보는 customer table에, 주소 정보는 address table 에 저장되어 있는 상태다 )

# %%
import pandas as pd

import MySQLdb


db = MySQLdb.connect(
    "db.fastcamp.us",  # DATABASE_HOST
    "root",  # DATABASE_USERNAME
    "dkstncks",  # DATABASE_PASSWORD
    "sakila",  # DATABASE_NAME
    charset='utf8',
)

cursor = db.cursor()

# %%
# 일단 그냥 한번 불러와보자. 어떤 일이 생기는지 살펴볼 필요가 있다.

SQL_QUERY = """
    SELECT COUNT(*) FROM customer;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#    COUNT(*)
# 0       599

# %%
SQL_QUERY = """
    SELECT COUNT(*) FROM address;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#    COUNT(*)
# 0       603

# %%
SQL_QUERY = """
    SELECT COUNT(*) FROM customer, address;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#    COUNT(*)
# 0    361197

# %%
# 599 * 603 => 361197

# %%
SQL_QUERY = """
    SELECT * FROM customer, address;
"""

df = pd.read_sql(SQL_QUERY, db)
df.head(5)
# Out:
#    customer_id  store_id first_name last_name  \
# 0            1         1       MARY     SMITH
# 1            2         1   PATRICIA   JOHNSON
# 2            3         1      LINDA  WILLIAMS
# 3            4         2    BARBARA     JONES
# 4            5         1  ELIZABETH     BROWN
#
#                                  email  address_id  active  \
# 0        MARY.SMITH@sakilacustomer.org           5       1
# 1  PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2    LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3     BARBARA.JONES@sakilacustomer.org           8       1
# 4   ELIZABETH.BROWN@sakilacustomer.org           9       1
#
#           create_date         last_update  address_id            address  \
# 0 2006-02-14 22:04:36 2006-02-15 04:57:20           1  47 MySakila Drive
# 1 2006-02-14 22:04:36 2006-02-15 04:57:20           1  47 MySakila Drive
# 2 2006-02-14 22:04:36 2006-02-15 04:57:20           1  47 MySakila Drive
# 3 2006-02-14 22:04:36 2006-02-15 04:57:20           1  47 MySakila Drive
# 4 2006-02-14 22:04:36 2006-02-15 04:57:20           1  47 MySakila Drive
#
#   address2 district  city_id postal_code phone         last_update
# 0     None  Alberta      300                   2014-09-25 22:30:27
# 1     None  Alberta      300                   2014-09-25 22:30:27
# 2     None  Alberta      300                   2014-09-25 22:30:27
# 3     None  Alberta      300                   2014-09-25 22:30:27
# 4     None  Alberta      300                   2014-09-25 22:30:27

# %%
# 제대로 된 정보를 얻으려면 이렇게 하셔야 합니다.

SQL_QUERY = """
    SELECT
        customer.*, address.address
    FROM customer, address
    WHERE
        customer.address_id = address.address_id
    ;
"""

pd.read_sql(SQL_QUERY, db).head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0            1         1       MARY     SMITH
# 1            2         1   PATRICIA   JOHNSON
# 2            3         1      LINDA  WILLIAMS
# 3            4         2    BARBARA     JONES
# 4            5         1  ELIZABETH     BROWN
#
#                                  email  address_id  active  \
# 0        MARY.SMITH@sakilacustomer.org           5       1
# 1  PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2    LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3     BARBARA.JONES@sakilacustomer.org           8       1
# 4   ELIZABETH.BROWN@sakilacustomer.org           9       1
#
#           create_date         last_update            address
# 0 2006-02-14 22:04:36 2006-02-15 04:57:20     1913 Hanoi Way
# 1 2006-02-14 22:04:36 2006-02-15 04:57:20   1121 Loja Avenue
# 2 2006-02-14 22:04:36 2006-02-15 04:57:20  692 Joliet Street
# 3 2006-02-14 22:04:36 2006-02-15 04:57:20   1566 Inegl Manor
# 4 2006-02-14 22:04:36 2006-02-15 04:57:20    53 Idfu Parkway

# %%
# 근데 이걸 효과적으로 하는 방법은 SQL JOIN을 사용하는 것이다.

SQL_QUERY = """
    SELECT customer.*, address
    FROM customer
    JOIN address ON customer.address_id = address.address_id
    ;
"""

pd.read_sql(SQL_QUERY, db).head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0            1         1       MARY     SMITH
# 1            2         1   PATRICIA   JOHNSON
# 2            3         1      LINDA  WILLIAMS
# 3            4         2    BARBARA     JONES
# 4            5         1  ELIZABETH     BROWN
#
#                                  email  address_id  active  \
# 0        MARY.SMITH@sakilacustomer.org           5       1
# 1  PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2    LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3     BARBARA.JONES@sakilacustomer.org           8       1
# 4   ELIZABETH.BROWN@sakilacustomer.org           9       1
#
#           create_date         last_update            address
# 0 2006-02-14 22:04:36 2006-02-15 04:57:20     1913 Hanoi Way
# 1 2006-02-14 22:04:36 2006-02-15 04:57:20   1121 Loja Avenue
# 2 2006-02-14 22:04:36 2006-02-15 04:57:20  692 Joliet Street
# 3 2006-02-14 22:04:36 2006-02-15 04:57:20   1566 Inegl Manor
# 4 2006-02-14 22:04:36 2006-02-15 04:57:20    53 Idfu Parkway

# %%
# 시간을 한번 재보자.

import time

# SELECT WHERE
start_time = time.clock()

SQL_QUERY = """
    SELECT
        customer.*, address.address
    FROM customer, address
    WHERE
        customer.address_id = address.address_id
    ;
"""

pd.read_sql(SQL_QUERY, db)

print("SELECT WHERE: {time}s".format(time=time.clock() - start_time))


# SELECT JOIN

start_time = time.clock()

SQL_QUERY = """
    SELECT customer.*, address
    FROM customer
    JOIN address ON customer.address_id = address.address_id
    ;
"""

pd.read_sql(SQL_QUERY, db)

print("SELECT JOIN : {time}s".format(time=time.clock() - start_time))
# Out:
# SELECT WHERE: 0.008726999999999485s
# SELECT JOIN : 0.0077099999999994395s
