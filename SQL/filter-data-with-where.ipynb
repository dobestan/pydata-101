# %%
import MySQLdb


db = MySQLdb.connect(
    "db.fastcamp.us",
    "root",
    "dkstncks",
    "world",
    charset='utf8',
)

cursor = db.cursor()

# %%
import pandas as pd

# %%
# SQL Perspective

SQL_QUERY = """
    SELECT *
    FROM Country
    WHERE
        Continent IN ("North America", "South America")
    ;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#    Code                              Name      Continent           Region  \
# 0   ABW                             Aruba  North America        Caribbean
# 1   AIA                          Anguilla  North America        Caribbean
# 2   ANT              Netherlands Antilles  North America        Caribbean
# 3   ARG                         Argentina  South America    South America
# 4   ATG               Antigua and Barbuda  North America        Caribbean
# 5   BHS                           Bahamas  North America        Caribbean
# 6   BLZ                            Belize  North America  Central America
# 7   BMU                           Bermuda  North America    North America
# 8   BOL                           Bolivia  South America    South America
# 9   BRA                            Brazil  South America    South America
# 10  BRB                          Barbados  North America        Caribbean
# 11  CAN                            Canada  North America    North America
# ...

# %%
# Pandas Perspective

SQL_QUERY = """
    SELECT *
    FROM Country
"""

df = pd.read_sql(SQL_QUERY, db)

# %%
df["Continent"].isin(["North America", "South America"])
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6       True
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25     False
# 26     False
# 27      True
# 28      True
# 29      True
#        ...
# 209    False
# 210    False
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# 216    False
# 217    False
# 218    False
# 219    False
# 220    False
# 221    False
# 222     True
# 223     True
# 224    False
# 225    False
# 226     True
# 227     True
# 228     True
# 229     True
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# Name: Continent, dtype: bool

# %%
df[df["Continent"].isin(["North America", "South America"])]
# Out:
#     Code                              Name      Continent           Region  \
# 0    ABW                             Aruba  North America        Caribbean
# 3    AIA                          Anguilla  North America        Caribbean
# 6    ANT              Netherlands Antilles  North America        Caribbean
# 8    ARG                         Argentina  South America    South America
# 13   ATG               Antigua and Barbuda  North America        Caribbean
# 24   BHS                           Bahamas  North America        Caribbean
# 27   BLZ                            Belize  North America  Central America
# 28   BMU                           Bermuda  North America    North America
# 29   BOL                           Bolivia  South America    South America
# 30   BRA                            Brazil  South America    South America
# 31   BRB                          Barbados  North America        Caribbean
# ...
